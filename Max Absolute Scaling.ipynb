# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.datasets import load_boston

# %%
data = load_boston()

# %%
dir(data)
# Out:
# ['DESCR', 'data', 'feature_names', 'filename', 'target']

# %%
data.data
# Out:
# array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#         4.9800e+00],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#         9.1400e+00],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#         4.0300e+00],
#        ...,
#        [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         5.6400e+00],
#        [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#         6.4800e+00],
#        [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         7.8800e+00]])

# %%
df = pd.DataFrame(data.data , columns = data.feature_names)

# %%
df['target'] = data.target

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  target
# 0     15.3  396.90   4.98    24.0
# 1     17.8  396.90   9.14    21.6
# 2     17.8  392.83   4.03    34.7
# 3     18.7  394.63   2.94    33.4
# 4     18.7  396.90   5.33    36.2

# %%
df = df [['CRIM','RM','LSTAT','target']]

# %%
df.head()
# Out:
#       CRIM     RM  LSTAT  target
# 0  0.00632  6.575   4.98    24.0
# 1  0.02731  6.421   9.14    21.6
# 2  0.02729  7.185   4.03    34.7
# 3  0.03237  6.998   2.94    33.4
# 4  0.06905  7.147   5.33    36.2

# %%
df.describe()
# Out:
#              CRIM          RM       LSTAT      target
# count  506.000000  506.000000  506.000000  506.000000
# mean     3.613524    6.284634   12.653063   22.532806
# std      8.601545    0.702617    7.141062    9.197104
# min      0.006320    3.561000    1.730000    5.000000
# 25%      0.082045    5.885500    6.950000   17.025000
# 50%      0.256510    6.208500   11.360000   21.200000
# 75%      3.677083    6.623500   16.955000   25.000000
# max     88.976200    8.780000   37.970000   50.000000

# %%
x = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.33,random_state=42)

# %%
x_train.shape , x_test.shape
# Out:
# ((339, 3), (167, 3))

# %%
from sklearn.preprocessing import MaxAbsScaler

# %%
sc = MaxAbsScaler()

# %%
sc.fit(x_train)
# Out:
# MaxAbsScaler()

# %%
x_train_scaled = sc.transform(x_train)
x_test_scaled = sc.transform(x_test)

# %%
sc.max_abs_
# Out:
# array([88.9762,  8.78  , 37.97  ])

# %%
x_train_scaled = pd.DataFrame(x_train_scaled,columns=x_train.columns)
x_test_scaled = pd.DataFrame(x_test_scaled,columns=x_test.columns)

# %%
x_train_scaled.head()
# Out:
#        CRIM        RM     LSTAT
# 0  0.115008  0.704442  0.474849
# 1  0.007552  0.662073  0.390045
# 2  0.001625  0.702961  0.504346
# 3  0.001251  0.681435  0.351593
# 4  0.001439  0.737358  0.323150

# %%
x_test_scaled.head()
# Out:
#        CRIM        RM     LSTAT
# 0  0.001032  0.730752  0.238083
# 1  0.000634  0.769704  0.092968
# 2  0.001188  0.681435  0.475902
# 3  0.001030  0.690774  0.145378
# 4  0.057208  0.717198  0.454833

# %% [markdown]
# ### Normal Data

# %%
np.round(x_train.describe())
# Out:
#         CRIM     RM  LSTAT
# count  339.0  339.0  339.0
# mean     3.0    6.0   12.0
# std      8.0    1.0    7.0
# min      0.0    4.0    2.0
# 25%      0.0    6.0    7.0
# 50%      0.0    6.0   11.0
# 75%      3.0    7.0   16.0
# max     89.0    9.0   38.0

# %%
np.round(x_test.describe())
# Out:
#         CRIM     RM  LSTAT
# count  167.0  167.0  167.0
# mean     4.0    6.0   13.0
# std     10.0    1.0    7.0
# min      0.0    4.0    3.0
# 25%      0.0    6.0    7.0
# 50%      0.0    6.0   12.0
# 75%      4.0    6.0   17.0
# max     74.0    9.0   37.0

# %% [markdown]
# #### Scaled Data

# %%
np.round(x_train_scaled.describe())
# Out:
#         CRIM     RM  LSTAT
# count  339.0  339.0  339.0
# mean     0.0    1.0    0.0
# std      0.0    0.0    0.0
# min      0.0    0.0    0.0
# 25%      0.0    1.0    0.0
# 50%      0.0    1.0    0.0
# 75%      0.0    1.0    0.0
# max      1.0    1.0    1.0

# %%
np.round(x_test_scaled.describe())
# Out:
#         CRIM     RM  LSTAT
# count  167.0  167.0  167.0
# mean     0.0    1.0    0.0
# std      0.0    0.0    0.0
# min      0.0    0.0    0.0
# 25%      0.0    1.0    0.0
# 50%      0.0    1.0    0.0
# 75%      0.0    1.0    0.0
# max      1.0    1.0    1.0

# %%
fig = plt.figure(figsize=(15,5))
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)

ax1.set_title('Before Scaling')
sns.kdeplot(x_train['CRIM'],ax=ax1)
sns.kdeplot(x_train['RM'],ax = ax1)
sns.kdeplot(x_train['LSTAT'],ax =ax1)

ax2.set_title('After Scalling')
sns.kdeplot(x_train_scaled['CRIM'],ax = ax2)
sns.kdeplot(x_train_scaled['RM'], ax = ax2)
sns.kdeplot(x_train_scaled['LSTAT'],ax=ax2)

plt.show()
